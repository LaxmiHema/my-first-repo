# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

driver = webdriver.Chrome()
driver.get('https://www.naukri.com/')
designation = driver.find_element(By.CLASS_NAME, "suggestor-input")
designation.send_keys("Data Analyst")

location = driver.find_element(By.XPATH,"/html/body/div[1]/div[7]/div/div/div[5]/div/div/div/div[1]/div/input")
location.send_keys("Banglore")

search = driver.find_element(By.CLASS_NAME, "qsbSubmit")
search.click()

time.sleep(10)
job_title =[]
job_location = []
company_name = []
experience_required = []

title_tags = driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_tags[0:10]:
   # title = i.text
    job_title.append(i.text)
    
    
location_tag = driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tag[0:10]:
    location = i.text
    job_location.append(location)
    
    
company_tag = driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tag[0:10]:
    company = i.text
    company_name.append(company)
    
    
    
experience_tag = driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')
for i in experience_tag[0:10]:
    experience = i.text
    experience_required.append(experience)
    
#print(job_title)  
df = pd.DataFrame({'Title':job_title,'Location':job_location, 'Company_Name':company_name, 'Experience':experience_required})

df
# Out:
#             Title                                           Location  \
# 0    Data Analyst  Gurgaon/ Gurugram, Haryana, Bangalore/ Bengalu...
# 1    Data Analyst                                Bangalore/Bengaluru
# 2    Data Analyst  Hyderabad/Secunderabad, Pune, Bangalore/Bengaluru
# 3  Data Analyst I                                Bangalore/Bengaluru
# 4    Data Analyst                                Bangalore/Bengaluru
# 5    Data Analyst                                Bangalore/Bengaluru
# 6    Data Analyst                       Chennai, Bangalore/Bengaluru
# 7    Data Analyst                                Bangalore/Bengaluru
# 8    Data Analyst  Bangalore/ Bengaluru, Karnataka(Hebbal Kempapura)
# 9    Data Analyst                                Bangalore/Bengaluru
#
#            Company_Name Experience
# 0             Delhivery    1-3 Yrs
# 1        Everest Vacuum    2-5 Yrs
# 2     Synchron Infotech    5-8 Yrs
# 3                Cerner   5-10 Yrs
# ...

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

driver = webdriver.Chrome()
driver.get('https://www.naukri.com/')
designation = driver.find_element(By.CLASS_NAME, "suggestor-input")
designation.send_keys("Data Scientist")

location = driver.find_element(By.XPATH,"/html/body/div[1]/div[7]/div/div/div[5]/div/div/div/div[1]/div/input")
location.send_keys("Banglore")

search = driver.find_element(By.CLASS_NAME, "qsbSubmit")
search.click()

time.sleep(10)
job_title =[]
job_location = []
company_name = []
experience_required = []

title_tags = driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_tags[0:10]:
   # title = i.text
    job_title.append(i.text)
    
    
location_tag = driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tag[0:10]:
    location = i.text
    job_location.append(location)
    
    
company_tag = driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tag[0:10]:
    company = i.text
    company_name.append(company)
    
    
    
experience_tag = driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')
for i in experience_tag[0:10]:
    experience = i.text
    experience_required.append(experience)
    
#print(job_title)  
df = pd.DataFrame({'Title':job_title,'Location':job_location, 'Company_Name':company_name, 'Experience':experience_required})

df
# Out:
#                                                Title  \
# 0                            Data Science Specialist
# 1                   Analystics & Modeling Specialist
# 2                  Data Scientist with Retail Domain
# 3                                     Data Scientist
# 4                                     Data Scientist
# 5                                     Data Scientist
# 6                                     Data Scientist
# 7                                     Data Scientist
# 8  ACN - Applied Intelligence - Finance - Data Sc...
# 9                              Senior Data Scientist
#
#                                             Location  \
# 0  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...
# 1  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...
# 2  Kolkata, Mumbai, Nagpur, Hyderabad/Secunderaba...
# 3  Noida, Kolkata, Mumbai, Hyderabad/Secunderabad...
# 4  Noida, Kolkata, Mumbai, Hyderabad/Secunderabad...
# 5  Noida, Kolkata, Mumbai, Hyderabad/Secunderabad...
# ...

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

driver = webdriver.Chrome()
driver.get('https://www.naukri.com/')
designation = driver.find_element(By.CLASS_NAME, "suggestor-input")
designation.send_keys("Data Analyst")

#location = driver.find_element(By.XPATH,"/html/body/div[1]/div[7]/div/div/div[5]/div/div/div/div[1]/div/input")
#location.send_keys("Banglore")

search = driver.find_element(By.CLASS_NAME, "qsbSubmit")
search.click()

time.sleep(10)
location = driver.find_element(By.XPATH, "/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[4]/div[2]/div[2]/label/i")
location.click()
time.sleep(5)
salary = driver.find_element(By.XPATH, "/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[5]/div[2]/div[2]/label/i")
salary.click()
time.sleep(10)
job_title =[]
job_location = []
company_name = []
experience_required = []

title_tags = driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_tags[0:10]:
   # title = i.text
    job_title.append(i.text)
    
    
location_tag = driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tag[0:10]:
    location = i.text
    job_location.append(location)
    
    
company_tag = driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tag[0:10]:
    company = i.text
    company_name.append(company)
    
    
    
experience_tag = driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')
for i in experience_tag[0:10]:
    experience = i.text
    experience_required.append(experience)
    
#print(job_title)  
df = pd.DataFrame({'Title':job_title,'Location':job_location, 'Company_Name':company_name, 'Experience':experience_required})

df
# Out:
#                   Title                                           Location  \
# 0          Data Analyst                                   Gurgaon/Gurugram
# 1          Data Analyst  Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...
# 2          Data Analyst  Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...
# 3          Data Analyst  Gurgaon/ Gurugram, Haryana, Chennai, Mumbai (A...
# 4          Data Analyst                                              Noida
# 5          Data Analyst                                              Noida
# 6          Data Analyst  Delhi / NCR, New Delhi, Delhi(Netaji Subhash P...
# 7          Data Analyst  Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...
# 8  Data Analyst - Delhi  Delhi / NCR, New Delhi, Delhi, Faridabad, Haryana
# 9          Data Analyst                            Gurgaon/Gurugram, Delhi
#
#                    Company_Name Experience
# 0        GM Analytics Solutions    2-5 Yrs
# 1      Volvo Financial Services    3-5 Yrs
# ...

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

driver = webdriver.Chrome()
driver.get('https://www.flipkart.com/')

time.sleep(5)

cross = driver.find_element(By.XPATH,'//button[@class="_2KpZ6l _2doB4z"]')
cross.click()

search_text = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input')
search_text.send_keys("Suglass")

search_button = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button')
search_button.click()

time.sleep(5)
brand = []
product_description = []
price = []
start_Page = 0
end_page = 2
for page in range(start_page,end_page):
    brand_tag = driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in brand_tag:
        brand.append(i.text)
    product_description_tag = driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
    for i in product_description_tag:
        product_description.append(i.text)
    
    
    price_tag = driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in price_tag:
        price.append(i.text)
        
        
    next_page = driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_page.click()
 

print(len(brand),len(product_description), len(price))
#df = pd.DataFrame({'Brand':brand, 'Product_Description':product_description, 'Price':price})

#df
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9312\1892948233.py in <module>
#      30     brand_tag = driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
#      31     for i in brand_tag:
# ---> 32         brand.append(i.text)
#      33     product_description_tag = driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
#      34     for i in product_description_tag:
#
# ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webelement.py in text(self)
#      88     def text(self) -> str:
#      89         """The text of the element."""
# ---> 90         return self._execute(Command.GET_ELEMENT_TEXT)["value"]
#      91
#      92     def click(self) -> None:
#
# ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     393             params = {}
# ...

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

driver = webdriver.Chrome()
driver.get('https://www.flipkart.com/apple-iphone-11-black-64-gb/product-reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY')

time.sleep(5)


rating = []
review_summery = []
full_review = []

start_page = 0
end_page = 10


for page in range(start_page, end_page):
    rating_tag = driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
    for i in rating_tag:
        rating.append(i.text)
    

    review_tag = driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
    for i in review_tag:
        review_summery.append(i.text)
    
    
    full_review_tag = driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
    for i in full_review_tag:
        full_review.append(i.text)
    
    
    next_page = driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_page.click()
    time.sleep(3)

    
    
    
df = pd.DataFrame({'Rating':rating, 'Review_Summery':review_summery, 'Full_Review':full_review})

df
# Out:
#    Rating     Review_Summery  \
# 0       5           Terrific
# 1       5     Classy product
# 2       5          Brilliant
# 3       5          Wonderful
# 4       5          Must buy!
# ..    ...                ...
# 95      5          Excellent
# 96      5          Fabulous!
# 97      5  Terrific purchase
# 98      5            Awesome
# 99      5     Simply awesome
#
#                                           Full_Review
# 0                                      Very very good
# 1   Camera is awesome\nBest battery backup\nA perf...
# 2                                    Excellent Phone.
# 3                              This is amazing at all
# 4                                 It’s really awesome
# ..                                                ...
# 95                                   Best camera ever
# 96  It’s very good battery life and display and vi...
# 97                                 Value for money 🖤🖤
# 98  I dreamt about this day from a long time.... G...
# ...

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

driver = webdriver.Chrome()
driver.get('https://www.flipkart.com/')

time.sleep(5)

cross = driver.find_element(By.XPATH,'//button[@class="_2KpZ6l _2doB4z"]')
cross.click()

search_text = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input')
search_text.send_keys("Sneaker")

search_button = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button')
search_button.click()

time.sleep(5)
brand = []
product_description = []
price = []

start_page = 0
end_page = 3

for page in range(start_page, end_page):
    brand_tag = driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in brand_tag:
        brand.append(i.text)
    
    product_description_tag = driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
    for i in product_description_tag:
        product_description.append(i.text)
    
    
    price_tag = driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in price_tag:
    

    
    
df = pd.DataFrame({'Brand':brand, 'Product_description':product_description, 'Price':price})

df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9312\3346900114.py in <module>
#      40
#      41
# ---> 42 df = pd.DataFrame({'Brand':brand, 'Product_description':product_description, 'Price':price})
#      43
#      44 df
#
# D:\Anaconda\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     634         elif isinstance(data, dict):
#     635             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637         elif isinstance(data, ma.MaskedArray):
#     638             import numpy.ma.mrecords as mrecords
#
# D:\Anaconda\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
# ...

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

driver = webdriver.Chrome()
driver.get('https://www.amazon.in/')

search_text = driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input')
search_text.send_keys("laptop")

search_button = driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input')
search_button.click()

time.sleep(3)
cpu_type = driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[6]/ul[7]/span[10]/li/span/a/div/label/i')
cpu_type.click()

time.sleep(5)

title = []
rating = []
price = []

title_tag = driver.find_elements(By.XPATH,'//span[@class="a-size-medium a-color-base a-text-normal"]')
for i in title_tag[0:24]:
    title.append(i.text)
    
    
rating_tag = driver.find_elements(By.XPATH,'//span[@class="a-icon-alt"]')
for i in rating_tag[0:24]:
    rating.append(i.text)
    

price_tag = driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]')
for i in price_tag[0:24]:
    price.append(i.text)
    
    
df = pd.DataFrame({'Title':title, 'Rating':rating, 'Price':price})

df
# Out:
#                                                 Title Rating   Price
# 0   Acer Aspire Lite 11th Gen Intel Core i5-1155G7...         45,990
# 1   Acer One 14 Laptop Intel Core i5 1135G7 (8GB R...         42,990
# 2   Xiaomi Notebook Ultra Max 11th Gen Intel Core ...         48,990
# 3   Xiaomi Notebook Pro Max 11th Gen Intel Core i5...         50,999
# 4   HP Laptop 15s, 12th Gen Intel Core i5-1235U, 1...         54,990
# 5   Dell Vostro 3420 Laptop,Intel i5-1135G7/8GB/51...         49,490
# 6   Acer Aspire Lite 11th Gen Intel Core i5-1155G7...         45,990
# 7   Dell Vostro 3510 Laptop,Intel i5-1135G7/8GB/1T...         52,490
# 8   Lenovo IdeaPad Slim 3 Intel Core i5 11th Gen 1...         50,990
# 9   Dell 14, Intel 12th Gen i5-1235U Laptop/8GB/51...         54,490
# 10  Acer Aspire 3 Intel Core i5 12th Generation (1...         51,990
# 11  HP [Smart Choice Victus Gaming Laptop 12th Gen...         70,490
# 12  HP 15s, 12th Gen Intel Core i5 16GB RAM/512GB ...         60,990
# ...

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

driver = webdriver.Chrome()
driver.get('https://www.azquotes.com/')

top_quotes = driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div[1]/div/div[3]/ul/li[5]/a')
top_quotes.click()


quote = []
author = []
types_of_quotes = []

quotes_tag = driver.find_elements(By.XPATH,'//a[@class="title"]')
for i in quotes_tag[0:100]:
    quote.append(i.text)
    
    
author_tag = driver.find_elements(By.XPATH,'//div[@class="author"]')
for i in author_tag[0:100]:
    author.append(i.text)
    
    
types_of_quotes_tag = driver.find_elements(By.XPATH,'//div[@class="tags"]')
for i in types_of_quotes_tag[0:100]:
    types_of_quotes.append(i.text)
    
    
df = pd.DataFrame({'QUOTES':quote, 'AUTHOR':author, 'TYPES_OF_QUOTES':types_of_quotes})

df
# Out:
#                                                QUOTES                AUTHOR  \
# 0   The essence of strategy is choosing what not t...        Michael Porter
# 1   One cannot and must not try to erase the past ...            Golda Meir
# 2   Patriotism means to stand by the country. It d...    Theodore Roosevelt
# 3   Death is something inevitable. When a man has ...        Nelson Mandela
# 4   You have to love a nation that celebrates its ...          Erma Bombeck
# ..                                                ...                   ...
# 95     When the going gets weird, the weird turn pro.    Hunter S. Thompson
# 96  When a train goes through a tunnel and it gets...       Corrie Ten Boom
# 97  If you think you are too small to make a diffe...            Dalai Lama
# 98  God doesn't require us to succeed, he only req...         Mother Teresa
# 99    Change your thoughts and you change your world.  Norman Vincent Peale
#
#                              TYPES_OF_QUOTES
# ...

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

driver = webdriver.Chrome()
driver.get('https://www.motor1.com/')

time.sleep(5)

feature_tag = driver.find_element(By.XPATH,'/html/body/div[8]/div[2]/div/div/div[3]/ul/li[3]')
feature_tag.click()


list_tag = driver.find_element(By.XPATH,'/html/body/div[8]/div[6]/div/a')
list_tag.click()

find_cars = driver.find_element(By.XPATH,'/html/body/div[8]/div[8]/div[3]/div[1]/div/div/div[1]/div/div[1]/h3/a')
find_cars.click()
#search_button = driver.find_element(By.XPATH,'//button[@class="m1-search-panel-button m1-search-form-button-animate icon-search-svg"]')
#search_button.click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8208\1303992097.py in <module>
#      12 time.sleep(5)
#      13
# ---> 14 feature_tag = driver.find_element(By.XPATH,'/html/body/div[8]/div[2]/div/div/div[3]/ul/li[3]')
#      15 feature_tag.click()
#      16
#
# ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     738             value = f'[name="{value}"]'
#     739
# --> 740         return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#     741
#     742     def find_elements(self, by=By.ID, value: Optional[str] = None) -> List[WebElement]:
#
# ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
# ...

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

driver = webdriver.Chrome()
driver.get(' https://www.jagranjosh.com/')


gk_options = driver.find_element(By.XPATH, '/html/body/div[1]/div[1]/div/div[1]/div/div[5]/div/div[1]/header/div[3]/ul/li[3]/a')
gk_options.click()


time.sleep(3)
all_prime_minister = driver.find_element(By.XPATH,'/html/body/div[1]/div/div/div[2]/div/div[10]/div/div/ul/li[2]/a')
all_prime_minister.click()


pm_name = []
born_death = [] 
term_of_office = []
remark = []

pm_tag = driver.find_elements(By.XPATH,'')
# Out:
# ---------------------------------------------------------------------------
# InvalidSelectorException                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9312\242908891.py in <module>
#      25 remark = []
#      26
# ---> 27 pm_tag = driver.find_elements(By.XPATH,'')
#
# ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webdriver.py in find_elements(self, by, value)
#     768         # Return empty list if driver returns null
#     769         # See https://github.com/SeleniumHQ/selenium/issues/4555
# --> 770         return self.execute(Command.FIND_ELEMENTS, {"using": by, "value": value})["value"] or []
#     771
#     772     @property
#
# ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     344         response = self.command_executor.execute(driver_command, params)
#     345         if response:
# ...
